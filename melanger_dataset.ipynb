# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
os.chdir ("C:\\Users\\Hp\\Desktop\\Chaimae\\stage\\PFE\\Dataset\\dataset_final")
cwd=os.getcwd()
print(cwd)
df=pd.read_excel('CTMAUTO.xlsx')
# Out:
# C:\Users\Hp\Desktop\Chaimae\stage\PFE\Dataset\dataset_final

# %%
df.head()
# Out:
#    Unnamed: 0 Ville de depart   Latitude  Longitude Ville d'arrivée  \
# 0           0          AGADIR  30.422036  -9.559509      AL HOCEIMA
# 1           1          AGADIR  30.422036  -9.559509     BENI MELLAL
# 2           2          AGADIR  30.422036  -9.559509       BERRECHID
# 3           3          AGADIR  30.422036  -9.559509      CASABLANCA
# 4           4          AGADIR  30.422037  -9.559509        ELJADIDA
#
#    Latitude.1  Longitude.1     Distance  duree        date_depart  \
# 0   35.245114    -3.930186  1014.802001   6:06  04/12/2019, 16:17
# 1   32.334193    -6.353335   461.149000  15:15  09/09/2019, 22:58
# 2   33.267675    -7.581147   424.626000  11:59  27/05/2019, 07:00
# 3   33.595063    -7.618777   464.517000  13:24  21/04/2019, 16:29
# 4   36.860370     6.925006   391.116000  13:54  10/03/2019, 15:31
#
#         date_arrivee      prix  nombre_place Moyen_de_transport
# 0  05/12/2019, 22:23  304.4406            33            autocar
# ...

# %%
from sklearn.utils import shuffle
result= shuffle(df)

# %%
result.head()
# Out:
#       Unnamed: 0 Ville de depart   Latitude  Longitude Ville d'arrivée  \
# 4545        3582       MARRAKECH  31.625826  -7.989161       KHOURIBGA
# 3908        2945           RABAT  34.022405  -6.834543           OUJDA
# 510          510      MOHAMMADIA  33.695838  -7.389329      AL HOCEIMA
# 6138        5175           NADOR  35.051918  -2.824399       KHOURIBGA
# 3276        2313      ERRACHIDIA  31.929089  -4.434081        INEZGANE
#
#       Latitude.1  Longitude.1    Distance  duree        date_depart  \
# 4545   32.885508    -6.909238  259.951000   5:40  07/11/2019, 20:54
# 3908   34.677874    -1.929306  516.788000   9:41  04/08/2019, 21:37
# 510    35.245114    -3.930186  531.404999  17:03  24/01/2020, 08:28
# 6138   32.885508    -6.909238  592.060000  12:53  04/04/2019, 06:31
# 3276   30.356293    -9.545935  606.621000  15:19  18/08/2019, 12:17
#
#            date_arrivee       prix  nombre_place Moyen_de_transport
# ...

# %%
result.to_excel("C:\\Users\\Hp\\Desktop\\Chaimae\\stage\\PFE\\Dataset\\dataset_final\\trajeeet.xlsx")

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
os.chdir ("C:\\Users\\Hp\\Desktop\\Chaimae\\stage\\PFE\\Dataset\\dataset_final")
cwd=os.getcwd()
print(cwd)
df1=pd.read_excel('VOi.xlsx')
# Out:
# C:\Users\Hp\Desktop\Chaimae\stage\PFE\Dataset\dataset_final

# %%
from sklearn.utils import shuffle
result1= shuffle(df1)

# %%
result1.head()
# Out:
#         Unnamed: 0  Unnamed: 0.1 Ville de depart   Latitude  Longitude  \
# 364765      364765      361381.0       BERRECHID  33.267675  -7.581147
# 611095      100111           NaN          MEKNES  42.651545  -1.309065
# 340484      340484      337100.0        KHENIFRA  32.935772  -5.669650
# 448424      448424      445040.0      AL HOCEIMA  35.245114  -3.930186
# 146227      146227      142843.0            SAFI  32.249414  -8.994165
#
#        Ville d'arrivée  Latitude.1  Longitude.1    Distance duree  \
# 364765      SIDI KACEM   34.226412    -5.711434  259.677999  2:47
# 611095         KENITRA   34.264570    -6.570169  145.169001  1:35
# 340484       BERRECHID   33.267675    -7.581147  235.012001  2:45
# 448424           RABAT   34.022405    -6.834543  461.113001  5:07
# 146227          SEFROU   33.824898    -4.833336  557.229000  5:09
#
#                 date_depart       date_arrivee       prix  nombre_place  \
# ...

# %%
res=pd.concat([result, result1],sort=False)

# %%
resu= shuffle(res)
resu.head()
# Out:
#         Unnamed: 0 Ville de depart   Latitude  Longitude Ville d'arrivée  \
# 375003      375003      ERRACHIDIA  31.929089  -4.434081         TETOUAN
# 394171      394171            TAZA  34.230155  -4.010104       KHEMISSET
# 75840        75840           NADOR  35.051918  -2.824399        ELJADIDA
# 308655      308655            SAFI  32.249414  -8.994165         BERKANE
# 628802      117818          TEMARA  33.917166  -6.923804      MOHAMMADIA
#
#         Latitude.1  Longitude.1    Distance duree          date_depart  \
# 375003   35.570175    -5.374278  672.971001  9:05  2019-03-20 09:58:00
# 394171   33.830287    -6.072605  230.191000  2:11  2019-03-20 08:36:00
# 75840    36.860370     6.925006  689.209999  6:34  2019-03-20 19:21:00
# 308655   34.926676    -2.329409  846.847000  7:54  2019-03-20 16:46:00
# 628802   33.695838    -7.389329   54.735000  0:38  2019-03-23 09:02:00
#
#              date_arrivee       prix  nombre_place Moyen_de_transport  \
# ...

# %%
resu.to_excel("C:\\Users\\Hp\\Desktop\\Chaimae\\stage\\PFE\\Dataset\\dataset_final\\trajeeet_entre ville_Maroc.xlsx")
