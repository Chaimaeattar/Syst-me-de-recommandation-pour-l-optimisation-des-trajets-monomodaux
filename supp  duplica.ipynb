# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
os.chdir ("C:\\Users\\Hp\\Desktop\\Chaimae\\stage\\PFE\\Dataset")
cwd=os.getcwd()
print(cwd)
df=pd.read_excel('dupli.xlsx')
# Out:
# C:\Users\Hp\Desktop\Chaimae\stage\PFE\Dataset

# %%
df.head()
# Out:
#   Ville de depart   Latitude  Longitude Ville d'arrivée  Latitude.1  \
# 0          AGADIR  30.422036  -9.559509      AL HOCEIMA   35.245114
# 1          AGADIR  30.422036  -9.559509      AL HOCEIMA   35.245114
# 2          AGADIR  30.422036  -9.559509      AL HOCEIMA   35.245114
# 3          AGADIR  30.422036  -9.559509      AL HOCEIMA   35.245114
# 4          AGADIR  30.422036  -9.559509      AL HOCEIMA   35.245114
#
#    Longitude.1
# 0    -3.930186
# 1    -3.930186
# 2    -3.930186
# 3    -3.930186
# 4    -3.930186

# %%
res=df.drop_duplicates(subset=["Ville de depart","Ville d'arrivée"], keep="first", inplace=False)
res
# Out:
#      Ville de depart    Latitude  Longitude Ville d'arrivée  Latitude.1  \
# 0             AGADIR   30.422036  -9.559509      AL HOCEIMA   35.245114
# 9             AGADIR   30.422036  -9.559509     BENI MELLAL   32.334193
# 14            AGADIR   30.422036  -9.559509       BERRECHID   33.267675
# 24            AGADIR   30.422036  -9.559509      CASABLANCA   33.595063
# 39            AGADIR   30.422037  -9.559509        ELJADIDA   36.860370
# 44            AGADIR   30.422037  -9.559509      ERRACHIDIA   31.929089
# 50            AGADIR   30.422037  -9.559509       ESSAOUIRA   31.511828
# 54            AGADIR   30.422037  -9.559509             FES   34.034653
# 65            AGADIR   30.422037  -9.559509         KENITRA   34.264570
# 75            AGADIR   30.422037  -9.559509       KHEMISSET   33.830287
# 82            AGADIR   30.422037  -9.559509        KHENIFRA   32.935772
# 86            AGADIR   30.422037  -9.559509       MARRAKECH   31.625826
# ...

# %%
res.to_excel("C:\\Users\\Hp\\Desktop\\Chaimae\\stage\\PFE\\Dataset\\suppduplicate.xlsx")

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
os.chdir ("C:\\Users\\Hp\\Desktop\\Chaimae\\stage\\PFE\\Dataset")
cwd=os.getcwd()
print(cwd)
df=pd.read_excel('repeat.xlsx')
# Out:
# C:\Users\Hp\Desktop\Chaimae\stage\PFE\Dataset

# %%
df.head()
# Out:
#   Ville de depart   Latitude  Longitude Ville d'arrivée  Latitude.1  \
# 0          AGADIR  30.422036  -9.559509      AL HOCEIMA   35.245114
# 1          AGADIR  30.422036  -9.559509     BENI MELLAL   32.334193
# 2          AGADIR  30.422036  -9.559509       BERRECHID   33.267675
# 3          AGADIR  30.422036  -9.559509      CASABLANCA   33.595063
# 4          AGADIR  30.422037  -9.559509        ELJADIDA   36.860370
#
#    Longitude.1     Distance  duree        date_depart       date_arrivee  \
# 0    -3.930186  1014.802001  10:02  04/12/2019, 16:17  05/12/2019, 02:19
# 1    -6.353335   461.149000   5:05  09/09/2019, 22:58  10/09/2019, 04:03
# 2    -7.581147   424.626000   3:59  27/05/2019, 07:00  27/05/2019, 10:59
# 3    -7.618777   464.517000   4:28  21/04/2019, 16:29  21/04/2019, 20:57
# 4     6.925006   391.116000   4:38  10/03/2019, 15:31  10/03/2019, 20:09
#
#        prix  nombre_place Moyen_de_transport
# 0  202.9604             2            Voiture
# ...

# %%
df["prix1"]=df["Distance"]*0.25
df["prix2"]=df["Distance"]*0.28
df["prix3"]=df["Distance"]*0.30

# %%
df
# Out:
#     Ville de depart    Latitude  Longitude Ville d'arrivée  Latitude.1  \
# 0            AGADIR   30.422036  -9.559509      AL HOCEIMA   35.245114
# 1            AGADIR   30.422036  -9.559509     BENI MELLAL   32.334193
# 2            AGADIR   30.422036  -9.559509       BERRECHID   33.267675
# 3            AGADIR   30.422036  -9.559509      CASABLANCA   33.595063
# 4            AGADIR   30.422037  -9.559509        ELJADIDA   36.860370
# 5            AGADIR   30.422037  -9.559509      ERRACHIDIA   31.929089
# 6            AGADIR   30.422037  -9.559509       ESSAOUIRA   31.511828
# 7            AGADIR   30.422037  -9.559509             FES   34.034653
# 8            AGADIR   30.422037  -9.559509         KENITRA   34.264570
# 9            AGADIR   30.422037  -9.559509       KHEMISSET   33.830287
# 10           AGADIR   30.422037  -9.559509        KHENIFRA   32.935772
# 11           AGADIR   30.422037  -9.559509       MARRAKECH   31.625826
# ...

# %%
df.head

# %%
df_repeated = pd.concat([df]*600, ignore_index=True)
df_repeated
# Out:
#       Ville de depart   Latitude  Longitude Ville d'arrivée  Latitude.1  \
# 0              AGADIR  30.422036  -9.559509      AL HOCEIMA   35.245114
# 1              AGADIR  30.422036  -9.559509     BENI MELLAL   32.334193
# 2              AGADIR  30.422036  -9.559509       BERRECHID   33.267675
# 3              AGADIR  30.422036  -9.559509      CASABLANCA   33.595063
# 4              AGADIR  30.422037  -9.559509        ELJADIDA   36.860370
# 5              AGADIR  30.422037  -9.559509      ERRACHIDIA   31.929089
# 6              AGADIR  30.422037  -9.559509       ESSAOUIRA   31.511828
# 7              AGADIR  30.422037  -9.559509             FES   34.034653
# 8              AGADIR  30.422037  -9.559509         KENITRA   34.264570
# 9              AGADIR  30.422037  -9.559509       KHEMISSET   33.830287
# 10             AGADIR  30.422037  -9.559509        KHENIFRA   32.935772
# 11             AGADIR  30.422037  -9.559509       MARRAKECH   31.625826
# ...

# %%
df.to_excel("C:\\Users\\Hp\\Desktop\\Chaimae\\stage\\PFE\\Dataset\\reepeat.xlsx")
