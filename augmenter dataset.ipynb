# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
os.chdir ("C:\\Users\\Hp\\Desktop\\Chaimae\\stage\\PFE\\Dataset\\dataset_final")
cwd=os.getcwd()
print(cwd)
df=pd.read_excel('Maroccorec.xlsx')
# Out:
# C:\Users\Hp\Desktop\Chaimae\stage\PFE\Dataset\dataset_final

# %%
df.head()
# Out:
#   Ville de depart   Latitude  Longitude Ville d'arrivée  Latitude.1  \
# 0          AGADIR  30.422036  -9.559509      AL HOCEIMA   35.245114
# 1          AGADIR  30.422036  -9.559509     BENI MELLAL   32.334193
# 2          AGADIR  30.422036  -9.559509       BERRECHID   33.267675
# 3          AGADIR  30.422036  -9.559509      CASABLANCA   33.595063
# 4          AGADIR  30.422037  -9.559509        ELJADIDA   36.860370
#
#    Longitude.1     Distance  duree        date_depart       date_arrivee  \
# 0    -3.930186  1014.802001  20:04  04/12/2019, 16:17  05/12/2019, 12:21
# 1    -6.353335   461.149000  10:10  09/09/2019, 22:58  10/09/2019, 09:08
# 2    -7.581147   424.626000   7:59  27/05/2019, 07:00  27/05/2019, 14:59
# 3    -7.618777   464.517000   8:56  21/04/2019, 16:29  22/04/2019, 01:25
# 4     6.925006   391.116000   9:16  10/03/2019, 15:31  11/03/2019, 00:47
#
#         prix  nombre_place Moyen_de_transport        Durée
# ...

# %%
df.drop(['date_depart', 'date_arrivee'], axis='columns', inplace=True)

# %%
df
# Out:
#     Ville de depart    Latitude  Longitude Ville d'arrivée  Latitude.1  \
# 0            AGADIR   30.422036  -9.559509      AL HOCEIMA   35.245114
# 1            AGADIR   30.422036  -9.559509     BENI MELLAL   32.334193
# 2            AGADIR   30.422036  -9.559509       BERRECHID   33.267675
# 3            AGADIR   30.422036  -9.559509      CASABLANCA   33.595063
# 4            AGADIR   30.422037  -9.559509        ELJADIDA   36.860370
# 5            AGADIR   30.422037  -9.559509      ERRACHIDIA   31.929089
# 6            AGADIR   30.422037  -9.559509       ESSAOUIRA   31.511828
# 7            AGADIR   30.422037  -9.559509             FES   34.034653
# 8            AGADIR   30.422037  -9.559509         KENITRA   34.264570
# 9            AGADIR   30.422037  -9.559509       KHEMISSET   33.830287
# 10           AGADIR   30.422037  -9.559509        KHENIFRA   32.935772
# 11           AGADIR   30.422037  -9.559509       MARRAKECH   31.625826
# ...

# %%
df1= pd.concat([df]*100, ignore_index=True)
df1
# Out:
#       Ville de depart    Latitude  Longitude Ville d'arrivée  Latitude.1  \
# 0              AGADIR   30.422036  -9.559509      AL HOCEIMA   35.245114
# 1              AGADIR   30.422036  -9.559509     BENI MELLAL   32.334193
# 2              AGADIR   30.422036  -9.559509       BERRECHID   33.267675
# 3              AGADIR   30.422036  -9.559509      CASABLANCA   33.595063
# 4              AGADIR   30.422037  -9.559509        ELJADIDA   36.860370
# 5              AGADIR   30.422037  -9.559509      ERRACHIDIA   31.929089
# 6              AGADIR   30.422037  -9.559509       ESSAOUIRA   31.511828
# 7              AGADIR   30.422037  -9.559509             FES   34.034653
# 8              AGADIR   30.422037  -9.559509         KENITRA   34.264570
# 9              AGADIR   30.422037  -9.559509       KHEMISSET   33.830287
# 10             AGADIR   30.422037  -9.559509        KHENIFRA   32.935772
# 11             AGADIR   30.422037  -9.559509       MARRAKECH   31.625826
# ...

# %%
from faker import Faker
from random import randint
df1['date_depart']=''
df1['heure_depart']=''
faker = Faker()
for i in range(84600):
    df1['date_depart'][i]=faker.date_between(start_date='-2y', end_date='-1y')
    df1['heure_depart'][i]=""+str(randint(6,23))+":"+str(randint(0,59))+""
# Out:
# C:\Users\Hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\Hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-2a4ce1fd9bc1> in <module>
#       6 for i in range(84600):
#       7     df1['date_depart'][i]=faker.date_between(start_date='-2y', end_date='-1y')
# ----> 8     df1['heure_depart'][i]=""+str(randint(6,23))+":"+str(randint(0,59))+""
#
# ...

# %%
df1['dt_dep']=''
df1['dt_dep']=df1['date_depart'].astype(str)+' '+df1['heure_depart'].astype(str)

# %%
from datetime import datetime 
from time import strptime
from datetime import timedelta

# %%
df1['dt_dep'] = df1['dt_dep'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d %H:%M'))

# %%
df1
# Out:
#      Ville de depart   Latitude  Longitude Ville d'arrivée  Latitude.1  \
# 0             AGADIR  30.422036  -9.559509      AL HOCEIMA   35.245114
# 1             AGADIR  30.422036  -9.559509     BENI MELLAL   32.334193
# 2             AGADIR  30.422036  -9.559509       BERRECHID   33.267675
# 3             AGADIR  30.422036  -9.559509      CASABLANCA   33.595063
# 4             AGADIR  30.422037  -9.559509        ELJADIDA   36.860370
# 5             AGADIR  30.422037  -9.559509      ERRACHIDIA   31.929089
# 6             AGADIR  30.422037  -9.559509       ESSAOUIRA   31.511828
# 7             AGADIR  30.422037  -9.559509             FES   34.034653
# 8             AGADIR  30.422037  -9.559509         KENITRA   34.264570
# 9             AGADIR  30.422037  -9.559509       KHEMISSET   33.830287
# 10            AGADIR  30.422037  -9.559509        KHENIFRA   32.935772
# 11            AGADIR  30.422037  -9.559509       MARRAKECH   31.625826
# ...

# %%
df1
# Out:
#      Ville de depart   Latitude  Longitude Ville d'arrivée  Latitude.1  \
# 0              OUJDA  34.677874  -1.929306             FES   34.034653
# 1              RABAT  34.022405  -6.834543          AGADIR   30.422037
# 2              RABAT  34.022405  -6.834543             FES   34.034653
# 3              RABAT  34.022405  -6.834543       MARRAKECH   31.625826
# 4              RABAT  34.022405  -6.834543          MEKNES   42.651545
# 5              RABAT  34.022405  -6.834543          TANGER   35.777103
# 6              OUJDA  34.677874  -1.929306             FES   34.034653
# 7              RABAT  34.022405  -6.834543          AGADIR   30.422037
# 8              RABAT  34.022405  -6.834543             FES   34.034653
# 9              RABAT  34.022405  -6.834543       MARRAKECH   31.625826
# 10             RABAT  34.022405  -6.834543          MEKNES   42.651545
# 11             RABAT  34.022405  -6.834543          TANGER   35.777103
# ...

# %%
df1['dt_arr'] = df1['dt_dep']+df1['Durée'].apply(lambda x: timedelta(minutes=x))
df1['dt_arr'] = df1['dt_arr'].apply (lambda x: x.strftime("%d/%m/%Y, %H:%M"))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Durée'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-251-e0640eca11a6> in <module>
# ...

# %%
df1
# Out:
#      Ville de depart   Latitude  Longitude Ville d'arrivée  Latitude.1  \
# 0               TAZA  34.230155  -4.010104             FES   34.034653
# 1             TEMARA  33.917166  -6.923804      CASABLANCA   33.595063
# 2             TEMARA  33.917166  -6.923804      MOHAMMADIA   33.695838
# 3               TAZA  34.230155  -4.010104             FES   34.034653
# 4             TEMARA  33.917166  -6.923804      CASABLANCA   33.595063
# 5             TEMARA  33.917166  -6.923804      MOHAMMADIA   33.695838
# 6               TAZA  34.230155  -4.010104             FES   34.034653
# 7             TEMARA  33.917166  -6.923804      CASABLANCA   33.595063
# 8             TEMARA  33.917166  -6.923804      MOHAMMADIA   33.695838
# 9               TAZA  34.230155  -4.010104             FES   34.034653
# 10            TEMARA  33.917166  -6.923804      CASABLANCA   33.595063
# 11            TEMARA  33.917166  -6.923804      MOHAMMADIA   33.695838
# ...

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
os.chdir ("C:\\Users\\Hp\\Desktop\\Chaimae\\stage\\PFE\\Dataset")
cwd=os.getcwd()
print(cwd)
df=pd.read_excel('agadirfre.xlsx')
# Out:
# C:\Users\Hp\Desktop\Chaimae\stage\PFE\Dataset

# %%
df
# Out:
#     Ville de depart   Latitude  Longitude Ville d'arrivée  Latitude.1  \
# 0            AGADIR  30.422036  -9.559509      AL HOCEIMA   35.245114
# 1            AGADIR  30.422036  -9.559509     BENI MELLAL   32.334193
# 2            AGADIR  30.422036  -9.559509       BERRECHID   33.267675
# 3            AGADIR  30.422036  -9.559509      CASABLANCA   33.595063
# 4            AGADIR  30.422037  -9.559509        ELJADIDA   36.860370
# 5            AGADIR  30.422037  -9.559509      ERRACHIDIA   31.929089
# 6            AGADIR  30.422037  -9.559509       ESSAOUIRA   31.511828
# 7            AGADIR  30.422037  -9.559509             FES   34.034653
# 8            AGADIR  30.422037  -9.559509         KENITRA   34.264570
# 9            AGADIR  30.422037  -9.559509       KHEMISSET   33.830287
# 10           AGADIR  30.422037  -9.559509        KHENIFRA   32.935772
# 11           AGADIR  30.422037  -9.559509       MARRAKECH   31.625826
# ...

# %%
df2= pd.concat([df]*4, ignore_index=True)
df2
# Out:
#      Ville de depart   Latitude  Longitude Ville d'arrivée  Latitude.1  \
# 0             AGADIR  30.422036  -9.559509      AL HOCEIMA   35.245114
# 1             AGADIR  30.422036  -9.559509     BENI MELLAL   32.334193
# 2             AGADIR  30.422036  -9.559509       BERRECHID   33.267675
# 3             AGADIR  30.422036  -9.559509      CASABLANCA   33.595063
# 4             AGADIR  30.422037  -9.559509        ELJADIDA   36.860370
# 5             AGADIR  30.422037  -9.559509      ERRACHIDIA   31.929089
# 6             AGADIR  30.422037  -9.559509       ESSAOUIRA   31.511828
# 7             AGADIR  30.422037  -9.559509             FES   34.034653
# 8             AGADIR  30.422037  -9.559509         KENITRA   34.264570
# 9             AGADIR  30.422037  -9.559509       KHEMISSET   33.830287
# 10            AGADIR  30.422037  -9.559509        KHENIFRA   32.935772
# 11            AGADIR  30.422037  -9.559509       MARRAKECH   31.625826
# ...

# %%
from faker import Faker
from random import randint
df2['date_depart']=''
df2['heure_depart']=''
faker = Faker()
for i in range(6480):
    df2['date_depart'][i]=faker.date_between(start_date='-1y', end_date='-1y')
    df2['heure_depart'][i]=""+str(randint(6,23))+":"+str(randint(0,59))+""
# Out:
# C:\Users\Hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\Hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df2['dt_dep']=''
df2['dt_dep']=df2['date_depart'].astype(str)+' '+df2['heure_depart'].astype(str)
from datetime import datetime 
from time import strptime
from datetime import timedelta
df2['dt_dep'] = df2['dt_dep'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d %H:%M'))
df2['dt_arr'] = df2['dt_dep']+df2['Durée'].apply(lambda x: timedelta(minutes=x))
df2['dt_arr'] = df2['dt_arr'].apply (lambda x: x.strftime("%d/%m/%Y, %H:%M"))

# %%
df2
# Out:
#      Ville de depart   Latitude  Longitude Ville d'arrivée  Latitude.1  \
# 0             MEKNES  42.651545  -1.309065      CASABLANCA   33.595063
# 1             MEKNES  42.651545  -1.309065             FES   34.034653
# 2             MEKNES  42.651545  -1.309065         KENITRA   34.264570
# 3             MEKNES  42.651545  -1.309065           RABAT   34.022405
# 4         MOHAMMADIA  33.695838  -7.389329      CASABLANCA   33.595063
# 5         MOHAMMADIA  33.695838  -7.389329        ELJADIDA   31.929089
# 6         MOHAMMADIA  33.695838  -7.389329         KENITRA   34.264570
# 7         MOHAMMADIA  33.695838  -7.389329           RABAT   34.022405
# 8         MOHAMMADIA  33.695838  -7.389329          TEMARA   33.917166
# 9             MEKNES  42.651545  -1.309065      CASABLANCA   33.595063
# 10            MEKNES  42.651545  -1.309065             FES   34.034653
# 11            MEKNES  42.651545  -1.309065         KENITRA   34.264570
# ...

# %%
res=pd.concat([df, df1],sort=False)

# %%
res
# Out:
#      Ville de depart   Latitude  Longitude Ville d'arrivée  Latitude.1  \
# 0             AGADIR  30.422036  -9.559509      AL HOCEIMA   35.245114
# 1             AGADIR  30.422036  -9.559509     BENI MELLAL   32.334193
# 2             AGADIR  30.422036  -9.559509       BERRECHID   33.267675
# 3             AGADIR  30.422036  -9.559509      CASABLANCA   33.595063
# 4             AGADIR  30.422037  -9.559509        ELJADIDA   36.860370
# 5             AGADIR  30.422037  -9.559509      ERRACHIDIA   31.929089
# 6             AGADIR  30.422037  -9.559509       ESSAOUIRA   31.511828
# 7             AGADIR  30.422037  -9.559509             FES   34.034653
# 8             AGADIR  30.422037  -9.559509         KENITRA   34.264570
# 9             AGADIR  30.422037  -9.559509       KHEMISSET   33.830287
# 10            AGADIR  30.422037  -9.559509        KHENIFRA   32.935772
# 11            AGADIR  30.422037  -9.559509       MARRAKECH   31.625826
# ...

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
os.chdir ("C:\\Users\\Hp\\Desktop\\Chaimae\\stage\\PFE\\Dataset")
cwd=os.getcwd()
print(cwd)
df=pd.read_excel('agadirfre.xlsx')
# Out:
# C:\Users\Hp\Desktop\Chaimae\stage\PFE\Dataset

# %% [raw]
# res

# %%
df.drop(['date_depart', 'date_arrivee'], axis='columns', inplace=True)
df3= pd.concat([df]*1200, ignore_index=True)

# %%
from faker import Faker
from random import randint
df3['date_depart']=''
df3['heure_depart']=''
faker = Faker()
for i in range(3600):
    df3['date_depart'][i]=faker.date_between(start_date='-1y', end_date='-1y')
    df3['heure_depart'][i]=""+str(randint(6,23))+":"+str(randint(0,59))+""
# Out:
# C:\Users\Hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\Hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df3
# Out:
#      Ville de depart   Latitude  Longitude Ville d'arrivée  Latitude.1  \
# 0              RABAT  34.022405  -6.834543      CASABLANCA   33.595063
# 1              RABAT  34.022405  -6.834543         KENITRA   34.264570
# 2              RABAT  34.022405  -6.834543      MOHAMMADIA   33.695838
# 3              RABAT  34.022405  -6.834543      CASABLANCA   33.595063
# 4              RABAT  34.022405  -6.834543         KENITRA   34.264570
# 5              RABAT  34.022405  -6.834543      MOHAMMADIA   33.695838
# 6              RABAT  34.022405  -6.834543      CASABLANCA   33.595063
# 7              RABAT  34.022405  -6.834543         KENITRA   34.264570
# 8              RABAT  34.022405  -6.834543      MOHAMMADIA   33.695838
# 9              RABAT  34.022405  -6.834543      CASABLANCA   33.595063
# 10             RABAT  34.022405  -6.834543         KENITRA   34.264570
# 11             RABAT  34.022405  -6.834543      MOHAMMADIA   33.695838
# ...

# %%
df3['dt_dep']=''
df3['dt_dep']=df3['date_depart'].astype(str)+' '+df3['heure_depart'].astype(str)
from datetime import datetime 
from time import strptime
from datetime import timedelta
df3['dt_dep'] = df3['dt_dep'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d %H:%M'))
df3['dt_arr'] = df3['dt_dep']+df3['Durée'].apply(lambda x: timedelta(minutes=x))
df3['dt_arr'] = df3['dt_arr'].apply (lambda x: x.strftime("%d/%m/%Y, %H:%M"))

# %%
df3
# Out:
#      Ville de depart  Latitude  Longitude Ville d'arrivée  Latitude.1  \
# 0            KENITRA  34.26457  -6.570169      CASABLANCA   33.595063
# 1            KENITRA  34.26457  -6.570169           RABAT   34.022405
# 2            KENITRA  34.26457  -6.570169      CASABLANCA   33.595063
# 3            KENITRA  34.26457  -6.570169           RABAT   34.022405
# 4            KENITRA  34.26457  -6.570169      CASABLANCA   33.595063
# 5            KENITRA  34.26457  -6.570169           RABAT   34.022405
# 6            KENITRA  34.26457  -6.570169      CASABLANCA   33.595063
# 7            KENITRA  34.26457  -6.570169           RABAT   34.022405
# 8            KENITRA  34.26457  -6.570169      CASABLANCA   33.595063
# 9            KENITRA  34.26457  -6.570169           RABAT   34.022405
# 10           KENITRA  34.26457  -6.570169      CASABLANCA   33.595063
# 11           KENITRA  34.26457  -6.570169           RABAT   34.022405
# ...

# %%
res1=pd.concat([res, df3])

# %%
res1
# Out:
#      Ville de depart   Latitude  Longitude Ville d'arrivée  Latitude.1  \
# 0              OUJDA  34.677874  -1.929306             FES   34.034653
# 1              RABAT  34.022405  -6.834543          AGADIR   30.422037
# 2              RABAT  34.022405  -6.834543             FES   34.034653
# 3              RABAT  34.022405  -6.834543       MARRAKECH   31.625826
# 4              RABAT  34.022405  -6.834543          MEKNES   42.651545
# 5              RABAT  34.022405  -6.834543          TANGER   35.777103
# 6              OUJDA  34.677874  -1.929306             FES   34.034653
# 7              RABAT  34.022405  -6.834543          AGADIR   30.422037
# 8              RABAT  34.022405  -6.834543             FES   34.034653
# 9              RABAT  34.022405  -6.834543       MARRAKECH   31.625826
# 10             RABAT  34.022405  -6.834543          MEKNES   42.651545
# 11             RABAT  34.022405  -6.834543          TANGER   35.777103
# ...

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
os.chdir ("C:\\Users\\Hp\\Desktop\\Chaimae\\stage\\PFE\\Dataset")
cwd=os.getcwd()
print(cwd)
df=pd.read_excel('agadirfre.xlsx')
# Out:
# C:\Users\Hp\Desktop\Chaimae\stage\PFE\Dataset

# %%
df.drop(['date_depart', 'date_arrivee'], axis='columns', inplace=True)
df4= pd.concat([df]*350, ignore_index=True)
df4
# Out:
#      Ville de depart   Latitude  Longitude Ville d'arrivée  Latitude.1  \
# 0               SAFI  32.249414  -8.994165       MARRAKECH   31.625826
# 1               SAFI  32.249414  -8.994165      CASABLANCA   33.595063
# 2             SEFROU  33.824898  -4.833336             FES   34.034653
# 3             TANGER  35.777103  -5.803792      CASABLANCA   33.595063
# 4             TANGER  35.777103  -5.803792             FES   34.034653
# 5             TANGER  35.777103  -5.803792         KENITRA   34.264570
# 6             TANGER  35.777103  -5.803792           RABAT   34.022405
# 7            TETOUAN  35.570175  -5.374278             FES   34.034653
# 8               SAFI  32.249414  -8.994165       MARRAKECH   31.625826
# 9               SAFI  32.249414  -8.994165      CASABLANCA   33.595063
# 10            SEFROU  33.824898  -4.833336             FES   34.034653
# 11            TANGER  35.777103  -5.803792      CASABLANCA   33.595063
# ...

# %%
from faker import Faker
from random import randint
df4['date_depart']=''
df4['heure_depart']=''
faker = Faker()
for i in range(2800):
    df4['date_depart'][i]=faker.date_between(start_date='-1y', end_date='-1y')
    df4['heure_depart'][i]=""+str(randint(6,23))+":"+str(randint(0,59))+""
# Out:
# C:\Users\Hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\Hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df4['dt_dep']=''
df4['dt_dep']=df4['date_depart'].astype(str)+' '+df4['heure_depart'].astype(str)
from datetime import datetime 
from time import strptime
from datetime import timedelta
df4['dt_dep'] = df4['dt_dep'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d %H:%M'))
df4['dt_arr'] = df4['dt_dep']+df3['Durée'].apply(lambda x: timedelta(minutes=x))
df4['dt_arr'] = df4['dt_arr'].apply (lambda x: x.strftime("%d/%m/%Y, %H:%M"))

# %%
df4
# Out:
#      Ville de depart   Latitude  Longitude Ville d'arrivée  Latitude.1  \
# 0               SAFI  32.249414  -8.994165       MARRAKECH   31.625826
# 1               SAFI  32.249414  -8.994165      CASABLANCA   33.595063
# 2             SEFROU  33.824898  -4.833336             FES   34.034653
# 3             TANGER  35.777103  -5.803792      CASABLANCA   33.595063
# 4             TANGER  35.777103  -5.803792             FES   34.034653
# 5             TANGER  35.777103  -5.803792         KENITRA   34.264570
# 6             TANGER  35.777103  -5.803792           RABAT   34.022405
# 7            TETOUAN  35.570175  -5.374278             FES   34.034653
# 8               SAFI  32.249414  -8.994165       MARRAKECH   31.625826
# 9               SAFI  32.249414  -8.994165      CASABLANCA   33.595063
# 10            SEFROU  33.824898  -4.833336             FES   34.034653
# 11            TANGER  35.777103  -5.803792      CASABLANCA   33.595063
# ...

# %%
res2=pd.concat([res1, df4])

# %%
res2
# Out:
#      Ville de depart   Latitude  Longitude Ville d'arrivée  Latitude.1  \
# 0              OUJDA  34.677874  -1.929306             FES   34.034653
# 1              RABAT  34.022405  -6.834543          AGADIR   30.422037
# 2              RABAT  34.022405  -6.834543             FES   34.034653
# 3              RABAT  34.022405  -6.834543       MARRAKECH   31.625826
# 4              RABAT  34.022405  -6.834543          MEKNES   42.651545
# 5              RABAT  34.022405  -6.834543          TANGER   35.777103
# 6              OUJDA  34.677874  -1.929306             FES   34.034653
# 7              RABAT  34.022405  -6.834543          AGADIR   30.422037
# 8              RABAT  34.022405  -6.834543             FES   34.034653
# 9              RABAT  34.022405  -6.834543       MARRAKECH   31.625826
# 10             RABAT  34.022405  -6.834543          MEKNES   42.651545
# 11             RABAT  34.022405  -6.834543          TANGER   35.777103
# ...

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
os.chdir ("C:\\Users\\Hp\\Desktop\\Chaimae\\stage\\PFE\\Dataset")
cwd=os.getcwd()
print(cwd)
df=pd.read_excel('agadirfre.xlsx')
df.drop(['date_depart', 'date_arrivee'], axis='columns', inplace=True)
df4= pd.concat([df]*150, ignore_index=True)
from faker import Faker
from random import randint
df4['date_depart']=''
df4['heure_depart']=''
faker = Faker()
for i in range(150):
    df4['date_depart'][i]=faker.date_between(start_date='-1y', end_date='-1y')
    df4['heure_depart'][i]=""+str(randint(6,23))+":"+str(randint(0,59))+""
df4['dt_dep']=''
df4['dt_dep']=df4['date_depart'].astype(str)+' '+df4['heure_depart'].astype(str)
from datetime import datetime 
from time import strptime
from datetime import timedelta
df4['dt_dep'] = df4['dt_dep'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d %H:%M'))
df4['dt_arr'] = df4['dt_dep']+df3['Durée'].apply(lambda x: timedelta(minutes=x))
df4['dt_arr'] = df4['dt_arr'].apply (lambda x: x.strftime("%d/%m/%Y, %H:%M"))
# Out:
# C:\Users\Hp\Desktop\Chaimae\stage\PFE\Dataset
# C:\Users\Hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# C:\Users\Hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
res3=pd.concat([res2, df4])

# %%
res3
# Out:
#      Ville de depart   Latitude  Longitude Ville d'arrivée  Latitude.1  \
# 0          BERRECHID  33.267675  -7.581147      CASABLANCA   33.595063
# 1          BERRECHID  33.267675  -7.581147        ELJADIDA   36.860370
# 2          BERRECHID  33.267675  -7.581147      CASABLANCA   33.595063
# 3          BERRECHID  33.267675  -7.581147        ELJADIDA   36.860370
# 4          BERRECHID  33.267675  -7.581147      CASABLANCA   33.595063
# 5          BERRECHID  33.267675  -7.581147        ELJADIDA   36.860370
# 6          BERRECHID  33.267675  -7.581147      CASABLANCA   33.595063
# 7          BERRECHID  33.267675  -7.581147        ELJADIDA   36.860370
# 8          BERRECHID  33.267675  -7.581147      CASABLANCA   33.595063
# 9          BERRECHID  33.267675  -7.581147        ELJADIDA   36.860370
# 10         BERRECHID  33.267675  -7.581147      CASABLANCA   33.595063
# 11         BERRECHID  33.267675  -7.581147        ELJADIDA   36.860370
# ...

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
os.chdir ("C:\\Users\\Hp\\Desktop\\Chaimae\\stage\\PFE\\Dataset")
cwd=os.getcwd()
print(cwd)
df=pd.read_excel('agadirfre.xlsx')
df.drop(['date_depart', 'date_arrivee'], axis='columns', inplace=True)
df4= pd.concat([df]*50, ignore_index=True)
from faker import Faker
from random import randint
df4['date_depart']=''
df4['heure_depart']=''
faker = Faker()
for i in range(50):
    df4['date_depart'][i]=faker.date_between(start_date='-1y', end_date='-1y')
    df4['heure_depart'][i]=""+str(randint(6,23))+":"+str(randint(0,59))+""
df4['dt_dep']=''
df4['dt_dep']=df4['date_depart'].astype(str)+' '+df4['heure_depart'].astype(str)
from datetime import datetime 
from time import strptime
from datetime import timedelta
df4['dt_dep'] = df4['dt_dep'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d %H:%M'))
df4['dt_arr'] = df4['dt_dep']+df3['Durée'].apply(lambda x: timedelta(minutes=x))
df4['dt_arr'] = df4['dt_arr'].apply (lambda x: x.strftime("%d/%m/%Y, %H:%M"))
# Out:
# C:\Users\Hp\Desktop\Chaimae\stage\PFE\Dataset
# C:\Users\Hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# C:\Users\Hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
res4=pd.concat([res3, df4])

# %%
res4
# Out:
#    Ville de depart   Latitude  Longitude Ville d'arrivée  Latitude.1  \
# 0           AGADIR  30.422037  -9.559509       ESSAOUIRA   31.511828
# 1           AGADIR  30.422037  -9.559509       ESSAOUIRA   31.511828
# 2           AGADIR  30.422037  -9.559509       ESSAOUIRA   31.511828
# 3           AGADIR  30.422037  -9.559509       ESSAOUIRA   31.511828
# 4           AGADIR  30.422037  -9.559509       ESSAOUIRA   31.511828
# 5           AGADIR  30.422037  -9.559509       ESSAOUIRA   31.511828
# 6           AGADIR  30.422037  -9.559509       ESSAOUIRA   31.511828
# 7           AGADIR  30.422037  -9.559509       ESSAOUIRA   31.511828
# 8           AGADIR  30.422037  -9.559509       ESSAOUIRA   31.511828
# 9           AGADIR  30.422037  -9.559509       ESSAOUIRA   31.511828
# 10          AGADIR  30.422037  -9.559509       ESSAOUIRA   31.511828
# 11          AGADIR  30.422037  -9.559509       ESSAOUIRA   31.511828
# 12          AGADIR  30.422037  -9.559509       ESSAOUIRA   31.511828
# ...

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
os.chdir ("C:\\Users\\Hp\\Desktop\\Chaimae\\stage\\PFE\\Dataset")
cwd=os.getcwd()
print(cwd)
df=pd.read_excel('agadirfre.xlsx')
df.drop(['date_depart', 'date_arrivee'], axis='columns', inplace=True)
df4= pd.concat([df]*120, ignore_index=True)
from faker import Faker
from random import randint
df4['date_depart']=''
df4['heure_depart']=''
faker = Faker()
for i in range(120):
    df4['date_depart'][i]=faker.date_between(start_date='-1y', end_date='-1y')
    df4['heure_depart'][i]=""+str(randint(6,23))+":"+str(randint(0,59))+""
df4['dt_dep']=''
df4['dt_dep']=df4['date_depart'].astype(str)+' '+df4['heure_depart'].astype(str)
from datetime import datetime 
from time import strptime
from datetime import timedelta
df4['dt_dep'] = df4['dt_dep'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d %H:%M'))
df4['dt_arr'] = df4['dt_dep']+df3['Durée'].apply(lambda x: timedelta(minutes=x))
df4['dt_arr'] = df4['dt_arr'].apply (lambda x: x.strftime("%d/%m/%Y, %H:%M"))
# Out:
# C:\Users\Hp\Desktop\Chaimae\stage\PFE\Dataset
# C:\Users\Hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# C:\Users\Hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
res5=pd.concat([res4, df4])

# %%
res5
# Out:
#     Ville de depart   Latitude  Longitude Ville d'arrivée  Latitude.1  \
# 0            AGADIR  30.422037  -9.559509       ESSAOUIRA   31.511828
# 1            AGADIR  30.422037  -9.559509       ESSAOUIRA   31.511828
# 2            AGADIR  30.422037  -9.559509       ESSAOUIRA   31.511828
# 3            AGADIR  30.422037  -9.559509       ESSAOUIRA   31.511828
# 4            AGADIR  30.422037  -9.559509       ESSAOUIRA   31.511828
# 5            AGADIR  30.422037  -9.559509       ESSAOUIRA   31.511828
# 6            AGADIR  30.422037  -9.559509       ESSAOUIRA   31.511828
# 7            AGADIR  30.422037  -9.559509       ESSAOUIRA   31.511828
# 8            AGADIR  30.422037  -9.559509       ESSAOUIRA   31.511828
# 9            AGADIR  30.422037  -9.559509       ESSAOUIRA   31.511828
# 10           AGADIR  30.422037  -9.559509       ESSAOUIRA   31.511828
# 11           AGADIR  30.422037  -9.559509       ESSAOUIRA   31.511828
# ...

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
os.chdir ("C:\\Users\\Hp\\Desktop\\Chaimae\\stage\\PFE\\Dataset")
cwd=os.getcwd()
print(cwd)
df=pd.read_excel('agadirfre.xlsx')
df.drop(['date_depart', 'date_arrivee'], axis='columns', inplace=True)
df4= pd.concat([df]*220, ignore_index=True)
from faker import Faker
from random import randint
df4['date_depart']=''
df4['heure_depart']=''
faker = Faker()
for i in range(220):
    df4['date_depart'][i]=faker.date_between(start_date='-1y', end_date='-1y')
    df4['heure_depart'][i]=""+str(randint(6,23))+":"+str(randint(0,59))+""
df4['dt_dep']=''
df4['dt_dep']=df4['date_depart'].astype(str)+' '+df4['heure_depart'].astype(str)
from datetime import datetime 
from time import strptime
from datetime import timedelta
df4['dt_dep'] = df4['dt_dep'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d %H:%M'))
df4['dt_arr'] = df4['dt_dep']+df3['Durée'].apply(lambda x: timedelta(minutes=x))
df4['dt_arr'] = df4['dt_arr'].apply (lambda x: x.strftime("%d/%m/%Y, %H:%M"))
# Out:
# C:\Users\Hp\Desktop\Chaimae\stage\PFE\Dataset
# C:\Users\Hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# C:\Users\Hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
res6=pd.concat([res5, df4])

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
os.chdir ("C:\\Users\\Hp\\Desktop\\Chaimae\\stage\\PFE\\Dataset")
cwd=os.getcwd()
print(cwd)
df=pd.read_excel('agadirfre.xlsx')
df.drop(['date_depart', 'date_arrivee'], axis='columns', inplace=True)
df4= pd.concat([df]*270, ignore_index=True)
from faker import Faker
from random import randint
df4['date_depart']=''
df4['heure_depart']=''
faker = Faker()
for i in range(270):
    df4['date_depart'][i]=faker.date_between(start_date='-1y', end_date='-1y')
    df4['heure_depart'][i]=""+str(randint(6,23))+":"+str(randint(0,59))+""
df4['dt_dep']=''
df4['dt_dep']=df4['date_depart'].astype(str)+' '+df4['heure_depart'].astype(str)
from datetime import datetime 
from time import strptime
from datetime import timedelta
df4['dt_dep'] = df4['dt_dep'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d %H:%M'))
df4['dt_arr'] = df4['dt_dep']+df3['Durée'].apply(lambda x: timedelta(minutes=x))
df4['dt_arr'] = df4['dt_arr'].apply (lambda x: x.strftime("%d/%m/%Y, %H:%M"))
# Out:
# C:\Users\Hp\Desktop\Chaimae\stage\PFE\Dataset
# C:\Users\Hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# C:\Users\Hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
res7=pd.concat([res6, df4])

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
os.chdir ("C:\\Users\\Hp\\Desktop\\Chaimae\\stage\\PFE\\Dataset")
cwd=os.getcwd()
print(cwd)
df=pd.read_excel('agadirfre.xlsx')
df.drop(['date_depart', 'date_arrivee'], axis='columns', inplace=True)
df4= pd.concat([df]*500, ignore_index=True)
from faker import Faker
from random import randint
df4['date_depart']=''
df4['heure_depart']=''
faker = Faker()
for i in range(500):
    df4['date_depart'][i]=faker.date_between(start_date='-1y', end_date='-1y')
    df4['heure_depart'][i]=""+str(randint(6,23))+":"+str(randint(0,59))+""
df4['dt_dep']=''
df4['dt_dep']=df4['date_depart'].astype(str)+' '+df4['heure_depart'].astype(str)
from datetime import datetime 
from time import strptime
from datetime import timedelta
df4['dt_dep'] = df4['dt_dep'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d %H:%M'))
df4['dt_arr'] = df4['dt_dep']+df3['Durée'].apply(lambda x: timedelta(minutes=x))
df4['dt_arr'] = df4['dt_arr'].apply (lambda x: x.strftime("%d/%m/%Y, %H:%M"))
# Out:
# C:\Users\Hp\Desktop\Chaimae\stage\PFE\Dataset
# C:\Users\Hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# C:\Users\Hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-ce06ae77d7b8> in <module>
#      21 from time import strptime
#      22 from datetime import timedelta
# ...

# %%
res7
# Out:
#     Ville de depart   Latitude  Longitude Ville d'arrivée  Latitude.1  \
# 0            AGADIR  30.422037  -9.559509       ESSAOUIRA   31.511828
# 1            AGADIR  30.422037  -9.559509       ESSAOUIRA   31.511828
# 2            AGADIR  30.422037  -9.559509       ESSAOUIRA   31.511828
# 3            AGADIR  30.422037  -9.559509       ESSAOUIRA   31.511828
# 4            AGADIR  30.422037  -9.559509       ESSAOUIRA   31.511828
# 5            AGADIR  30.422037  -9.559509       ESSAOUIRA   31.511828
# 6            AGADIR  30.422037  -9.559509       ESSAOUIRA   31.511828
# 7            AGADIR  30.422037  -9.559509       ESSAOUIRA   31.511828
# 8            AGADIR  30.422037  -9.559509       ESSAOUIRA   31.511828
# 9            AGADIR  30.422037  -9.559509       ESSAOUIRA   31.511828
# 10           AGADIR  30.422037  -9.559509       ESSAOUIRA   31.511828
# 11           AGADIR  30.422037  -9.559509       ESSAOUIRA   31.511828
# ...

# %%
df.tail(6)
# Out:
#   Ville de depart   Latitude  Longitude Ville d'arrivée  Latitude.1  \
# 0       BERRECHID  33.267675  -7.581147      CASABLANCA   33.595063
# 1       BERRECHID  33.267675  -7.581147        ELJADIDA   36.860370
#
#    Longitude.1  Distance duree    prix  nombre_place Moyen_de_transport  \
# 0    -7.618777    39.395  0:38   7.879             2            Voiture
# 1     6.925006   101.220  1:08  20.244             1            Voiture
#
#        Durée
# 0  38.366667
# 1  68.450000

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
os.chdir ("C:\\Users\\Hp\\Desktop\\Chaimae\\stage\\PFE\\Dataset")
cwd=os.getcwd()
print(cwd)
df=pd.read_excel('agadirfre.xlsx')
# Out:
# C:\Users\Hp\Desktop\Chaimae\stage\PFE\Dataset

# %%
df.head()
# Out:
#   Ville de depart   Latitude  Longitude Ville d'arrivée  Latitude.1  \
# 0       BERRECHID  33.267675  -7.581147      CASABLANCA   33.595063
# 1       BERRECHID  33.267675  -7.581147        ELJADIDA   36.860370
#
#    Longitude.1  Distance duree        date_depart       date_arrivee    prix  \
# 0    -7.618777    39.395  0:38  23/10/2019, 20:21  23/10/2019, 20:59   7.879
# 1     6.925006   101.220  1:08  07/12/2019, 17:06  07/12/2019, 18:14  20.244
#
#    nombre_place Moyen_de_transport      Durée
# 0             2            Voiture  38.366667
# 1             1            Voiture  68.450000

# %%
df4= pd.concat([df]*500, ignore_index=True)
from faker import Faker
from random import randint
df4['date_depart']=''
df4['heure_depart']=''
faker = Faker()
for i in range(500):
    df4['date_depart'][i]=faker.date_between(start_date='-1y', end_date='-1y')
    df4['heure_depart'][i]=""+str(randint(6,23))+":"+str(randint(0,59))+""
# Out:
# C:\Users\Hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df4['dt_dep']=''
df4['dt_dep']=df4['date_depart'].astype(str)+' '+df4['heure_depart'].astype(str)

# %%
from datetime import datetime 
from time import strptime
from datetime import timedelta

# %%
df4
# Out:
#     Ville de depart   Latitude  Longitude Ville d'arrivée  Latitude.1  \
# 0         BERRECHID  33.267675  -7.581147      CASABLANCA   33.595063
# 1         BERRECHID  33.267675  -7.581147        ELJADIDA   36.860370
# 2         BERRECHID  33.267675  -7.581147      CASABLANCA   33.595063
# 3         BERRECHID  33.267675  -7.581147        ELJADIDA   36.860370
# 4         BERRECHID  33.267675  -7.581147      CASABLANCA   33.595063
# 5         BERRECHID  33.267675  -7.581147        ELJADIDA   36.860370
# 6         BERRECHID  33.267675  -7.581147      CASABLANCA   33.595063
# 7         BERRECHID  33.267675  -7.581147        ELJADIDA   36.860370
# 8         BERRECHID  33.267675  -7.581147      CASABLANCA   33.595063
# 9         BERRECHID  33.267675  -7.581147        ELJADIDA   36.860370
# 10        BERRECHID  33.267675  -7.581147      CASABLANCA   33.595063
# 11        BERRECHID  33.267675  -7.581147        ELJADIDA   36.860370
# ...

# %%
res.to_excel("C:\\Users\\Hp\\Desktop\\Chaimae\\stage\\PFE\\Dataset\\dataset_final\\CTMAUTO.xlsx")
